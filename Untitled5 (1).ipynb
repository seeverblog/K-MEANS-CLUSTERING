# %%
# !git clone https://github.com/seeverblog/RD_GLCM.git
# Out:
# Cloning into 'RD_GLCM'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 142 (delta 1), reused 0 (delta 0), pack-reused 130
# Receiving objects: 100% (142/142), 23.42 MiB | 41.28 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import os
os.chdir('/content/RD_GLCM/')
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/content/RD_GLCM/image/test/class 1/1592_right_resized.tif')
plt.axis("off")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
img.shape
# Out:
# (315, 500, 3)

# %%
img2=cv2.imread('/content/RD_GLCM/image/test/class 1/1592_right_resized.tif')
Z=img2.reshape((-1,3))
print(Z.shape)
# Out:
# (157500, 3)

# %%
Z=np.float32(Z)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 50, 45.0)
k=25
ret,label,center=cv2.kmeans(Z,K,None,criteria,5,cv2.KMEANS_RANDOM_CENTERS)

# %%
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

# %%
plt.imshow(cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))
plt.axis("off")
cv2.imwrite("k-clustering.jpg",cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))
# Out:
# True
